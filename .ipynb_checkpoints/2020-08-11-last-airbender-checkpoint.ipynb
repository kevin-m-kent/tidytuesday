# %%
using Pkg
Pkg.update() # You may need to update your local packages first
Pkg.add("Plots")
# Out:
#    Updating registry at `~/.julia/registries/General`
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
#   Resolving package versions...
#   Installed FFMPEG_jll ────────────────── v4.3.1+1
#   Installed DataValueInterfaces ───────── v1.0.0
#   Installed x265_jll ──────────────────── v3.0.0+2
#   Installed LibVPX_jll ────────────────── v1.9.0+0
#   Installed StructArrays ──────────────── v0.4.4
#   Installed Contour ───────────────────── v0.5.4
#   Installed Plots ─────────────────────── v1.5.8
#   Installed GeometryTypes ─────────────── v0.8.3
#   Installed Measures ──────────────────── v0.3.1
#   Installed libass_jll ────────────────── v0.14.0+3
#   Installed DataAPI ───────────────────── v1.3.0
#   Installed RecipesBase ───────────────── v1.0.2
#   Installed Showoff ───────────────────── v0.3.1
#   Installed IteratorInterfaceExtensions ─ v1.0.0
#   Installed StaticArrays ──────────────── v0.12.4
# ...

# %%
import Plots
Plots.plot(rand(4,4))

# %%
using CSV
using HTTP

# %%
response = HTTP.get("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-08-11/avatar.csv")
# Out:
# HTTP.Messages.Response:
# """
# HTTP/1.1 200 OK
# Connection: keep-alive
# Content-Length: 3661874
# Cache-Control: max-age=300
# Content-Security-Policy: default-src 'none'; style-src 'unsafe-inline'; sandbox
# Content-Type: text/plain; charset=utf-8
# ETag: "549eec35a35796e6b404e442725d9c776b12b8e7e9ffc4bd227824689ad82c44"
# Strict-Transport-Security: max-age=31536000
# X-Content-Type-Options: nosniff
# X-Frame-Options: deny
# X-XSS-Protection: 1; mode=block
# Via: 1.1 varnish (Varnish/6.0)
# X-GitHub-Request-Id: A0F8:691D:12C9E0:16E4C0:5F3697D3
# Accept-Ranges: bytes
# Date: Fri, 14 Aug 2020 13:55:32 GMT
# Via: 1.1 varnish
# X-Served-By: cache-bos4625-BOS
# X-Cache: MISS, MISS
# X-Cache-Hits: 0, 0
# X-Timer: S1597413332.219923,VS0,VE301
# Vary: Authorization,Accept-Encoding
# Access-Control-Allow-Origin: *
# X-Fastly-Request-ID: 6303699d6b472bd4f04c5d619a8ed703fe3611d0
# Expires: Fri, 14 Aug 2020 14:00:32 GMT
# Source-Age: 0
#
# ...

# %%
using DataFrames

df = CSV.File(response.body) |> DataFrame
# Out:
# 13385×11 DataFrame. Omitted printing of 7 columns
# │ Row   │ id    │ book   │ book_num │ chapter                            │
# │       │ Int64 │ String │ Int64    │ String                             │
# ├───────┼───────┼────────┼──────────┼────────────────────────────────────┤
# │ 1     │ 1     │ Water  │ 1        │ The Boy in the Iceberg             │
# │ 2     │ 2     │ Water  │ 1        │ The Boy in the Iceberg             │
# │ 3     │ 3     │ Water  │ 1        │ The Boy in the Iceberg             │
# │ 4     │ 4     │ Water  │ 1        │ The Boy in the Iceberg             │
# │ 5     │ 5     │ Water  │ 1        │ The Boy in the Iceberg             │
# │ 6     │ 6     │ Water  │ 1        │ The Boy in the Iceberg             │
# │ 7     │ 7     │ Water  │ 1        │ The Boy in the Iceberg             │
# │ 8     │ 8     │ Water  │ 1        │ The Boy in the Iceberg             │
# │ 9     │ 9     │ Water  │ 1        │ The Boy in the Iceberg             │
# ...

# %%
by(df, :director, nrow)
# Out:
# 7×2 DataFrame
# │ Row │ director                │ nrow  │
# │     │ String                  │ Int64 │
# ├─────┼─────────────────────────┼───────┤
# │ 1   │ Dave Filoni             │ 1797  │
# │ 2   │ Lauren MacMullan        │ 2698  │
# │ 3   │ Giancarlo Volpe         │ 4060  │
# │ 4   │ Anthony Lioi            │ 446   │
# │ 5   │ Ethan Spaulding         │ 2585  │
# │ 6   │ Michael Dante DiMartino │ 197   │
# │ 7   │ Joaquim Dos Santos      │ 1602  │
